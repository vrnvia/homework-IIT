# %% [markdown]
# # Титульный лист
# <a name = 'Титульный_лист'>

# %% [markdown]
# <font face="times new roman" size="3" color="black">
# <center> МИНИСТЕРСТВО ЦИФРОВОГО РАЗВИТИЯ, СВЯЗИ И МАССОВЫХ КОММУНИКАЦИЙ РОССИЙСКОЙ ФЕДЕРАЦИИ </center>
# <center>Ордена Трудового Красного Знамени федеральное государственное бюджетное образовательное учреждение высшего образования </center>
# <center> <strong> «Московский технический университет связи и информатики» </strong> </center>
#
#   <hr>
# <center> Кафедра «Телевидения и звукового вещания им. С.И. Катаева (ТиЗВ)» </center>
# <br>
# <center> <font face="times new roman" size="3" color="black"> Отчет по практическая работе № «12»</center>
# <center>по дисциплине </center>
# <center><b>«Введение в информационные технологии»</b></center>
# <center>на тему</center>
# <center><b>«Системы контроля версий»</b> </center>
#
# </font>
#
#   <br><br><br><br><br>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Выполнил: студент группы </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black">       БИК2303 </p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Воронов Илья Алексеевич</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Проверил:</p>
#   <p  align="right"> <font face="times new roman" size="3" color="black"> Ассистент кафедры ТиЗВ Кудряшов Всеволод Владимирович </p>
#   <br>
#   <br>
#
#   <p  align="center"> <font face="times new roman" size="2" color="black"> Москва, 2023 г. </p>
#
#   <hr>

# %% [markdown]
# ## Содержание

# %% [markdown]
# [1. Постановка задач](#Постановка_задач)
#
# [2. Ход работы](#Ход_работы)
#
# [3. Результат выполнения работы](#Результат_выполнения_работы)

# %% [markdown]
# #Постановка задач
# <a name = 'Постановка_задач'>

# %% [markdown]
# ##Задание
# <a name = '1'>

# %% [markdown]
# <ol type='circle'>
#   <p align="justify"><li> Установить GIT.
#   <li> Создать локальный репозиторий.
#   <li> Создать файл отчета по выполнению практической работы и поместить его в репозиторий
#   <li> Зафиксируйте в отчете все проделанные шаги и создайте версию отчета в GIT
#   <li>Создайте ветку отчета в GIT, добавьте описания шагов в отчет и создайте версию отчета в новой ветке.
#   <li> Слейте последнее изменение отчета в основную ветку.
#   <li>Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект на githab.
#   <li> Слейте последнее изменение отчета в основную ветку.
#    <li>Регистрируемся на github (или используем уже существующий аккаунт), создаем проект «homework IIT», залете содержимое из локального репозитория в проект.
#      <li>Разместить на github ранее созданный статический сайт.Доп. задание – Разметить на github ранее созданный динамический сайт.
#         <li>Завершить отчет, добавив описание всех пунктов.
# </p>
# <ul>

# %% [markdown]
# ##Цель работы
# <a name = '2'>

# %% [markdown]
# Локальный репозиторий и репозиторий на github

# %% [markdown]
# ##Задачи работы
# <a name = '3'>

# %% [markdown]
# <ol type='circle'>
# <p align="justify"><li>Установить git(систему контроля версий) для windows
# <li>  Создать локальный репозиторий, поместить в него файл отчета и создать его ветку
# <li> Зарегестрироваться на сайте github.com и загрузить на него ранее созданный динамический или статический сайт</p>

# %% [markdown]
# ##Расчет входных данных
# <a name = '4'>

# %% [markdown]
# <p align="justify">В ходе работы были использованы следующие инструменты и материалы:<br>
# 1. Использование системы контроля версий GIT<br>
# 2. Использование локального репозитория на базе GIT for windows<br>
# 3. Использование удаленного репозитория github.com<br>
# 4. Использование файла отчета</p>

# %% [markdown]
# #Ход работы
# <a name = 'Ход_работы'>

# %% [markdown]
# ### Задание 1
# <a name = 'Задание_1'></a>
# <p align="justify">Установить GIT.</p>

# %% [markdown]
# Устанавливаем GIT с оффициального сайта

# %% [markdown]
# ###Задание 2
# <a name = 'Задание_2'></a>
# <p align="justify">Создать локальный репозиторий.</p>

# %% [markdown]
# Заходим в Git Bash, создаем папку и переходим в нее(команда "cd"). Создаем репозиторий командой "git init" (См. Рисунок 1)
#
# ![g2.png](data:image/png;base64,...)
# *Рисунок 1*
